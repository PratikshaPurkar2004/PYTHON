# %%
import pandas as pd

# %%
df=pd.read_csv("online food delivery dataset.csv")

# %%
occupation_feedback=df.groupby(['Occupation','Feedback']).size().reset_index(name="Number of customers")
print(occupation_feedback)
# Out:
#        Occupation   Feedback  Number of customers
# 0        Employee  Negative                    33
# 1        Employee   Positive                   85
# 2      House wife  Negative                     1
# 3      House wife   Positive                    8
# 4  Self Employeed  Negative                    16
# 5  Self Employeed   Positive                   38
# 6         Student  Negative                    21
# 7         Student   Positive                  186
