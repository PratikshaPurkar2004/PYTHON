# %%
class BankAccount:
        def __init__(self,acc_num,owner_name,balance):
                self.acc_num=acc_num
                self.owner_name=owner_name
                self.balance=balance

# %%
acc1=BankAccount("1234567","John",1000.0)
acc2=BankAccount("7654321","Smith",1500.0)

# %%
print(acc1.acc_num)
print(acc2.owner_name)
# Out:
# 1234567
# Smith
