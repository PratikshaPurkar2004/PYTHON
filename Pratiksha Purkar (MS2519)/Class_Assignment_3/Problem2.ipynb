# %%
import pandas as pd

# %%
df=pd.read_csv("online food delivery dataset.csv")
print(df['Age'].mean())
# Out:
# 24.628865979381445

# %%
print(df['Age'].min())
# Out:
# 18

# %%
print(df['Age'].max())
# Out:
# 33

# %%
female=(df['Gender']=="Female").sum()
print(female)
# Out:
# 166

# %%
male=(df['Gender']=='Male').sum()
print(male)
# Out:
# 222
