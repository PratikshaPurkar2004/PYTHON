# %%
import pandas as pd

# %%
df=pd.read_csv("online food delivery dataset.csv")
avg_age=df.groupby('Occupation')["Age"].mean()
print(avg_age)
# Out:
# Occupation
# Employee          26.576271
# House wife        30.333333
# Self Employeed    26.388889
# Student           22.811594
# Name: Age, dtype: float64

# %%
highest_avg_age=avg_age.idxmax()
print(highest_avg_age)
# Out:
# House wife
