# %%
class Vehicle:
    def __init__(self,brand):
        self.brand=brand

    def move(self):
        print("the vehicle is moving!")

class Car(Vehicle):
    pass

car1=Car("Toyota")
print("Brand::",car1.brand)
car1.move()
# Out:
# Brand:: Toyota
# the vehicle is moving!
