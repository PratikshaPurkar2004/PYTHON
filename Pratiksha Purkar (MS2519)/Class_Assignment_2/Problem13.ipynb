# %%
import numpy as np

# %%
experiment_A=np.array([12, 15, 14, 18, 20, 17, 16])
experiment_B=np.array([10, 13, 15, 16, 19, 21, 18])
print(experiment_A)
print(experiment_B)
# Out:
# [12 15 14 18 20 17 16]
# [10 13 15 16 19 21 18]

# %%
mean_A=np.mean(experiment_A)
print(mean_A)
# Out:
# 16.0

# %%
mean_b=np.mean(experiment_B)
print(experiment_B)
# Out:
# [10 13 15 16 19 21 18]

# %%
std_A=np.std(experiment_A)
print(std_A)
# Out:
# 2.449489742783178

# %%
std_B=np.std(experiment_B)
print(std_B)
# Out:
# 3.4641016151377544

# %%
max_A=np.max(experiment_A)
print(max_A)
# Out:
# 20

# %%
max_B=np.max(experiment_B)
print(max_B)
# Out:
# 21

# %%
min_A=np.min(experiment_A)
print(min_A)
# Out:
# 12

# %%
min_B=np.min(experiment_B)
print(min_B)
# Out:
# 10

# %%
diff=experiment_A-experiment_B
print(diff)
# Out:
# [ 2  2 -1  2  1 -4 -2]

# %%
if std_A >std_B:
    print("Experiment A shows greater variation\n")
elif std_B >std_A:
    print("Experiment B shows greater variation\n")
else:
    print("Both experiments show equal variation\n")
# Out:
# Experiment B shows greater variation
