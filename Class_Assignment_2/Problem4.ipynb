# %%
import numpy as np

# %%
num=np.random.permutation(np.arange(1,51))
even_num=num[num%2==0]
odd_num=num[num%2!=0]
print(num)
# Out:
# [ 7 35 49 28  9 43  5 26  2 14 46 47 31 15 27 32 33 21 34 16 12 38 18 48
#  23  6 25 42  3 37 30 39 41 20  4 13 36 44 22 24 40  1 17 29 11 45  8 50
#  19 10]

# %%
print(even_num)
# Out:
# [28 26  2 14 46 32 34 16 12 38 18 48  6 42 30 20  4 36 44 22 24 40  8 50
#  10]

# %%
print(odd_num)
# Out:
# [ 7 35 49  9 43  5 47 31 15 27 33 21 23 25  3 37 39 41 13  1 17 29 11 45
#  19]
