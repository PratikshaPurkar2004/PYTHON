# %%
dict1={'Pratiksha':83.5,'shraddha':75,'sanika':60,'sayli':85}
print(dict1)
name=input("enter a Name::")
print(name)
if name in dict1:
    print("Marks:",dict1[name])
else:
    print("Strudent not found!")
# Out:
# {'Pratiksha': 83.5, 'shraddha': 75, 'sanika': 60, 'sayli': 85}
# Pratiksha
# Marks: 83.5

# %%
print(dict1.keys())
# Out:
# dict_keys(['Pratiksha', 'shraddha', 'sanika', 'sayli'])

# %%
print(dict1.values())
# Out:
# dict_values([83.5, 75, 60, 85])
