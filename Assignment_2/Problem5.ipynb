# %%
str=input("Enter a string::")
# reversedStr=str[::-1]
# print(reversedStr)
# if reversedStr==str:
#     print("Palindrome")
# else:
#     print("Not Palindrome")

str=str.replace(" ","").lower()
print(str)
reversedStr=""
for ch in str:
    reversedStr=ch+reversedStr
if reversedStr==str:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# neveroddoreven
# Palindrome
