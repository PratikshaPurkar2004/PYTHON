# %%
str=input("Enter a string::")
print(str)
frequency={}
for ch in str:
    if ch in frequency:
        frequency[ch]+=1
    else:
        frequency=1
for ch,count in frequency.items():
    print(ch,":",count)
# Out:
# banana
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 frequency={}
#       4 for ch in str:
# ----> 5     if ch in frequency:
#       6         frequency[ch]+=1
#       7     else:
#
# TypeError: argument of type 'int' is not iterable
