# %%
# list1=[]
# for i in range(5):
#     mark=int(input("Enter a number of marks::"))
#     list1.append(mark)
# marks=tuple(list1)
# highestMark=marks[0]
# lowestMark=marks[0]
# for i in marks: 
#     if highestMark<i:
#         highestMark=i
# for i in marks:
#     if lowestMark>i:
#         lowestMark=i
# print("Highest Marks::",highestMark)
# print("Lowest Marks::",lowestMark)

marks=tuple(map(int,input("Enter a marks::").split()))
highest=max(marks)
lowest=min(marks)
avg=sum(marks)/len(marks)
count=0
for i in marks:
    if i>avg:
        count+=1
print(marks)
print("Higest marks::",highest)
print("Lowest marks::",lowest)
print("Student above Average::",count)
# Out:
# (50, 60, 70, 80, 90)
# Higest marks:: 90
# Lowest marks:: 50
# Student above Average:: 2
