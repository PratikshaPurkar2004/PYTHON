# %%
list1=[]
for i in range(5):
    mark=float(input("Enter a marks::"))
    list1.append(mark)
print(list1)
avg=sum(list1)/5
if mark>90:
    grade="A"
elif mark>75:
    grade="B"
elif mark>60:
    grade="C"
else:
    grade="Fail"
print("Avarage",avg)
print(grade)
# Out:
# [10.0, 20.0, 30.0, 40.0, 50.0]
# Avarage 30.0
# Fail
